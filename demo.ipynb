# %% [markdown]
# # Instructions:
#
# * Clone https://github.com/jammm/Phantom: `git clone https://github.com/jammm/Phantom`
# * Place this demo notebook within the cloned `Phantom` folder.
# * Create a venv: `python3 -m venv .venv`
# * Activate the venv: `source .venv/bin/activate`
# * Start a jupyter notebook server after `pip install jupyter`, or use VS Code jupyter extension, then run the notebook sever from the `Phantom` folder such that the $PWD is `Phantom` folder
# * Run all the cells from top to bottom
# * In the last cell, change parameters, prompts, input images as necessary and click "Generate Video"

# %%
import os
if os.environ.get("VIRTUAL_ENV") == None or os.environ.get("VIRTUAL_ENV") == "":
    raise Exception("ERROR: no venv found. Make sure to create one with 'python3 -m venv .venv' and activate it with 'source .venv/bin/activate'")

print("Using venv: ", os.environ.get("VIRTUAL_ENV"))
# Out:
# Using venv:  /home/jam/jam/log-linear-attention/venv

# %%
print("Installing dependencies...")
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/rocm6.4
# !pip install -r requirements.txt

# Download models
# !pip install "huggingface_hub[cli]" ipywidgets

# !huggingface-cli download Wan-AI/Wan2.1-T2V-1.3B --local-dir ./Wan2.1-T2V-1.3B
# !huggingface-cli download bytedance-research/Phantom --local-dir ./Phantom-Wan-Models
# Out:
# Installing dependencies...
# DEPRECATION: Loading egg at /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages/causal_conv1d-1.5.0.post8-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Looking in indexes: https://download.pytorch.org/whl/nightly/rocm6.4
# Requirement already satisfied: torch in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (2.8.0.dev20250606+rocm6.4)
# Requirement already satisfied: torchvision in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (0.23.0.dev20250607+rocm6.4)
# Requirement already satisfied: torchaudio in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (2.8.0.dev20250607+rocm6.4)
# Requirement already satisfied: filelock in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: pytorch-triton-rocm==3.3.1+gitc8757738 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch) (3.3.1+gitc8757738)
# Requirement already satisfied: numpy in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# DEPRECATION: Loading egg at /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages/causal_conv1d-1.5.0.post8-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: torch>=2.4.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.8.0.dev20250606+rocm6.4)
# Requirement already satisfied: torchvision>=0.19.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.23.0.dev20250607+rocm6.4)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (4.11.0.86)
# Requirement already satisfied: diffusers>=0.31.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.33.1)
# Requirement already satisfied: transformers>=4.49.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (4.52.4)
# Requirement already satisfied: tokenizers>=0.20.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.21.1)
# Requirement already satisfied: accelerate>=1.1.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: tqdm in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: imageio in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.37.0)
# Requirement already satisfied: easydict in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.13)
# Requirement already satisfied: ftfy in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (6.3.1)
# Requirement already satisfied: dashscope in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.23.4)
# Requirement already satisfied: imageio-ffmpeg in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: flash_attn in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (2.7.4.post1)
# Requirement already satisfied: gradio>=5.0.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (5.33.0)
# Requirement already satisfied: numpy<2,>=1.23.5 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (1.26.4)
# Requirement already satisfied: xfuser>=0.4.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (0.4.3.post3)
# Requirement already satisfied: filelock in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: setuptools in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (2024.10.0)
# Requirement already satisfied: pytorch-triton-rocm==3.3.1+gitc8757738 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.3.1+gitc8757738)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from torchvision>=0.19.0->-r requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: importlib-metadata in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (8.7.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (0.32.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: requests in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: packaging>=20.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from transformers>=4.49.0->-r requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from transformers>=4.49.0->-r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: psutil in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from accelerate>=1.1.1->-r requirements.txt (line 7)) (7.0.0)
# Requirement already satisfied: wcwidth in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ftfy->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: aiohttp in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from dashscope->-r requirements.txt (line 12)) (3.12.11)
# Requirement already satisfied: websocket-client in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from dashscope->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: einops in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from flash_attn->-r requirements.txt (line 14)) (0.8.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.115.12)
# Requirement already satisfied: ffmpy in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (1.10.2)
# Requirement already satisfied: groovy~=0.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (3.10.18)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.11.5)
# Requirement already satisfied: pydub in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.11.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.34.3)
# Requirement already satisfied: websockets<16.0,>=10.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from gradio-client==1.10.2->gradio>=5.0.0->-r requirements.txt (line 15)) (15.0.1)
# Requirement already satisfied: sentencepiece>=0.1.99 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (4.13.4)
# Requirement already satisfied: distvae in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (0.0.0b5)
# Requirement already satisfied: yunchang>=0.6.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (0.6.3.post1)
# Requirement already satisfied: pytest in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (8.4.0)
# Requirement already satisfied: idna>=2.8 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio>=5.0.0->-r requirements.txt (line 15)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio>=5.0.0->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from beautifulsoup4>=4.12.3->xfuser>=0.4.1->-r requirements.txt (line 17)) (2.7)
# Requirement already satisfied: certifi in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.0.0->-r requirements.txt (line 15)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.0.0->-r requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=5.0.0->-r requirements.txt (line 15)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers>=0.31.0->-r requirements.txt (line 4)) (1.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.0.0->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.0.0->-r requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (14.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (1.20.0)
# Requirement already satisfied: zipp>=3.20 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from importlib-metadata->diffusers>=0.31.0->-r requirements.txt (line 4)) (3.23.0)
# Requirement already satisfied: iniconfig>=1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pytest->xfuser>=0.4.1->-r requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pytest->xfuser>=0.4.1->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pytest->xfuser>=0.4.1->-r requirements.txt (line 17)) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from requests->diffusers>=0.31.0->-r requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from requests->diffusers>=0.31.0->-r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: six>=1.5 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (0.1.2)
# DEPRECATION: Loading egg at /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages/causal_conv1d-1.5.0.post8-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: huggingface_hub[cli] in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (0.32.4)
# Requirement already satisfied: filelock in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (1.1.3)
# Requirement already satisfied: InquirerPy==0.3.4 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.51)
# Requirement already satisfied: comm>=0.1.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipywidgets) (9.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (2025.4.26)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/jam/jam/log-linear-attention/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 widgetsnbextension-4.0.14
# Fetching 22 files: 100%|██████████████████████| 22/22 [00:00<00:00, 4155.21it/s]
# /home/jam/jam/Phantom/Wan2.1-T2V-1.3B
# Fetching 39 files: 100%|██████████████████████| 39/39 [00:00<00:00, 2520.77it/s]
# /home/jam/jam/Phantom/Phantom-Wan-Models
# Looking in indexes: https://download.pytorch.org/whl/nightly/rocm6.4
# Requirement already satisfied: torch in ./venv/lib/python3.12/site-packages (2.8.0.dev20250606+rocm6.4)
# Requirement already satisfied: torchvision in ./venv/lib/python3.12/site-packages (0.23.0.dev20250607+rocm6.4)
# Requirement already satisfied: torchaudio in ./venv/lib/python3.12/site-packages (2.8.0.dev20250607+rocm6.4)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in ./venv/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: pytorch-triton-rocm==3.3.1+gitc8757738 in ./venv/lib/python3.12/site-packages (from torch) (3.3.1+gitc8757738)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./venv/lib/python3.12/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: torch>=2.4.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.8.0.dev20250606+rocm6.4)
# Requirement already satisfied: torchvision>=0.19.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.23.0.dev20250607+rocm6.4)
# Requirement already satisfied: opencv-python>=4.9.0.80 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (4.11.0.86)
# Requirement already satisfied: diffusers>=0.31.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.33.1)
# Requirement already satisfied: transformers>=4.49.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (4.52.4)
# Requirement already satisfied: tokenizers>=0.20.3 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.21.1)
# Requirement already satisfied: accelerate>=1.1.1 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: imageio in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.37.0)
# Requirement already satisfied: easydict in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.13)
# Requirement already satisfied: ftfy in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (6.3.1)
# Requirement already satisfied: dashscope in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.23.4)
# Requirement already satisfied: imageio-ffmpeg in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: flash_attn in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (2.7.4.post1)
# Requirement already satisfied: gradio>=5.0.0 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (5.33.0)
# Requirement already satisfied: numpy<2,>=1.23.5 in ./venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (1.26.4)
# Requirement already satisfied: xfuser>=0.4.1 in /home/jam/jam/xDiT (from -r requirements.txt (line 17)) (0.4.3.post3)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: setuptools in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (2024.10.0)
# Requirement already satisfied: pytorch-triton-rocm==3.3.1+gitc8757738 in ./venv/lib/python3.12/site-packages (from torch>=2.4.0->-r requirements.txt (line 1)) (3.3.1+gitc8757738)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./venv/lib/python3.12/site-packages (from torchvision>=0.19.0->-r requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: importlib-metadata in ./venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (8.7.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in ./venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (0.32.4)
# Requirement already satisfied: regex!=2019.12.17 in ./venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in ./venv/lib/python3.12/site-packages (from diffusers>=0.31.0->-r requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.12/site-packages (from transformers>=4.49.0->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.12/site-packages (from transformers>=4.49.0->-r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: psutil in ./venv/lib/python3.12/site-packages (from accelerate>=1.1.1->-r requirements.txt (line 7)) (7.0.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.12/site-packages (from ftfy->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.12/site-packages (from dashscope->-r requirements.txt (line 12)) (3.12.11)
# Requirement already satisfied: websocket-client in ./venv/lib/python3.12/site-packages (from dashscope->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: einops in ./venv/lib/python3.12/site-packages (from flash_attn->-r requirements.txt (line 14)) (0.8.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.115.12)
# Requirement already satisfied: ffmpy in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.2 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (1.10.2)
# Requirement already satisfied: groovy~=0.1 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (3.10.18)
# Requirement already satisfied: pandas<3.0,>=1.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.11.5)
# Requirement already satisfied: pydub in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.11.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./venv/lib/python3.12/site-packages (from gradio>=5.0.0->-r requirements.txt (line 15)) (0.34.3)
# Requirement already satisfied: websockets<16.0,>=10.0 in ./venv/lib/python3.12/site-packages (from gradio-client==1.10.2->gradio>=5.0.0->-r requirements.txt (line 15)) (15.0.1)
# Requirement already satisfied: sentencepiece>=0.1.99 in ./venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in ./venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (4.13.4)
# Requirement already satisfied: distvae in ./venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (0.0.0b5)
# Requirement already satisfied: yunchang>=0.6.0 in ./venv/lib/python3.12/site-packages (from xfuser>=0.4.1->-r requirements.txt (line 17)) (0.6.3.post1)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio>=5.0.0->-r requirements.txt (line 15)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.12/site-packages (from anyio<5.0,>=3.0->gradio>=5.0.0->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4>=4.12.3->xfuser>=0.4.1->-r requirements.txt (line 17)) (2.7)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.0.0->-r requirements.txt (line 15)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio>=5.0.0->-r requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=5.0.0->-r requirements.txt (line 15)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./venv/lib/python3.12/site-packages (from huggingface-hub>=0.27.0->diffusers>=0.31.0->-r requirements.txt (line 4)) (1.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.0.0->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.0.0->-r requirements.txt (line 15)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.12/site-packages (from pydantic<2.12,>=2.0->gradio>=5.0.0->-r requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in ./venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (14.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.12/site-packages (from aiohttp->dashscope->-r requirements.txt (line 12)) (1.20.0)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.12/site-packages (from importlib-metadata->diffusers>=0.31.0->-r requirements.txt (line 4)) (3.22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->diffusers>=0.31.0->-r requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests->diffusers>=0.31.0->-r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=5.0.0->-r requirements.txt (line 15)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.0.0->-r requirements.txt (line 15)) (0.1.2)
# Requirement already satisfied: huggingface_hub[cli] in ./venv/lib/python3.12/site-packages (0.32.4)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (1.1.3)
# Requirement already satisfied: InquirerPy==0.3.4 in ./venv/lib/python3.12/site-packages (from huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in ./venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in ./venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.51)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests->huggingface_hub[cli]) (2025.4.26)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# Fetching 22 files: 100%|█████████████████████| 22/22 [00:00<00:00, 13861.30it/s]
# /home/jam/jam/Phantom/Wan2.1-T2V-1.3B
# Fetching 39 files: 100%|██████████████████████| 39/39 [00:00<00:00, 2797.40it/s]
# /home/jam/jam/Phantom/Phantom-Wan-Models

# %%
import os
os.environ["OMP_NUM_THREADS"] = "16"

import ipywidgets as widgets
from IPython.display import display, clear_output
import subprocess
import glob
from IPython.display import Video

# Create interactive widgets for video generation parameters
print("🎬 Phantom Video Generation Configuration")
print("=" * 50)

# Text area for prompt
prompt_widget = widgets.Textarea(
    value="A cartoon old grandfather wearing a yellow hat, a yellow top and brown suspenders is holding a blue steaming coffee cup in a fresh cartoon-style cafe decorated with pink and blue tables and chairs, colorful chandeliers and colorful balls. The picture style is cartoony and fresh.",
    placeholder="Enter your video generation prompt here...",
    description="Prompt:",
    layout=widgets.Layout(width='100%', height='120px'),
    style={'description_width': '80px'}
)

# Resolution inputs
width_widget = widgets.IntText(
    value=832,
    description="Width:",
    style={'description_width': '80px'}
)

height_widget = widgets.IntText(
    value=480,
    description="Height:",
    style={'description_width': '80px'}
)

# Reference images input
ref_images_widget = widgets.Text(
    value="examples/ref14.png,examples/ref15.png,examples/ref16.png",
    placeholder="Comma-separated image paths",
    description="Ref Images:",
    layout=widgets.Layout(width='100%'),
    style={'description_width': '80px'}
)

# Number of frames
frames_widget = widgets.IntText(
    value=121,
    description="Frames:",
    style={'description_width': '80px'}
)

# FPS
fps_widget = widgets.IntText(
    value=24,
    description="FPS:",
    style={'description_width': '80px'}
)

# Advanced settings (collapsed by default)
advanced_accordion = widgets.Accordion(children=[
    widgets.VBox([
        widgets.Text(value="./Wan2.1-T2V-1.3B", description="Checkpoint Dir:", style={'description_width': '120px'}),
        widgets.Text(value="./Phantom-Wan-Models", description="Phantom Ckpt:", style={'description_width': '120px'}),
        widgets.IntText(value=8, description="Ulysses Size:", style={'description_width': '120px'}),
        widgets.IntText(value=1, description="Ring Size:", style={'description_width': '120px'}),
        widgets.IntText(value=8, description="Num GPUs:", style={'description_width': '120px'})
    ])
])
advanced_accordion.set_title(0, 'Advanced Settings')
advanced_accordion.selected_index = None  # Collapsed by default

# Generate button
generate_button = widgets.Button(
    description="🎬 Generate Video",
    button_style='success',
    layout=widgets.Layout(width='200px', height='40px')
)

def on_generate_click(b):
    # Get values from widgets
    prompt = prompt_widget.value
    width = width_widget.value
    height = height_widget.value
    ref_images = ref_images_widget.value
    frames = frames_widget.value
    fps = fps_widget.value
    
    # Get advanced settings
    advanced_widgets = advanced_accordion.children[0].children
    ckpt_dir = advanced_widgets[0].value
    phantom_ckpt = advanced_widgets[1].value
    ulysses_size = advanced_widgets[2].value
    ring_size = advanced_widgets[3].value
    num_gpus = advanced_widgets[4].value
    
    # Validate inputs
    if not prompt.strip():
        print("❌ Please enter a prompt!")
        return
    if not ref_images.strip():
        print("❌ Please enter reference image paths!")
        return
    if width <= 0 or height <= 0:
        print("❌ Width and height must be positive!")
        return
    if frames <= 0 or fps <= 0:
        print("❌ Frames and FPS must be positive!")
        return
    
    # Build command
    command = [
        "torchrun", f"--nproc_per_node={num_gpus}", "generate.py",
        "--task", "s2v-14B",
        "--size", f"{width}*{height}",
        "--frame_num", str(frames),
        "--sample_fps", str(fps),
        "--ckpt_dir", ckpt_dir,
        "--phantom_ckpt", phantom_ckpt,
        "--ref_image", ref_images,
        "--dit_fsdp",
        "--t5_fsdp",
        "--ulysses_size", str(ulysses_size),
        "--ring_size", str(ring_size),
        "--prompt", prompt
    ]
    
    print("🚀 Starting Phantom video generation...")
    print(f"📐 Resolution: {width}x{height}")
    print(f"🎞️ Frames: {frames} @ {fps} FPS")
    print(f"🖼️ Reference images: {ref_images}")
    print(f"💬 Prompt: {prompt[:100]}{'...' if len(prompt) > 100 else ''}")
    print("\n" + "="*50)
    
    # Run the command
    try:
        print("⏳ Running video generation (this may take several minutes)...")
        print("📺 Check your terminal/stdout for detailed progress output...")
        
        # Run command with output going to stdout/terminal
        result = subprocess.run(command, cwd=".")
        
        if result.returncode == 0:
            clear_output(wait=True)
            print("✅ Video generation completed successfully!")
            
            # Look for generated video files
            video_patterns = ["*.mp4", "*.avi", "*.mov", "*.mkv", "*.webm"]
            video_files = []
            
            for pattern in video_patterns:
                video_files.extend(glob.glob(pattern))
            
            # Also check in common output directories
            output_dirs = ["./outputs", "./results", "./generated", "."]
            for output_dir in output_dirs:
                if os.path.exists(output_dir):
                    for pattern in video_patterns:
                        video_files.extend(glob.glob(os.path.join(output_dir, pattern)))
            
            # Remove duplicates and sort by modification time (newest first)
            video_files = list(set(video_files))
            if video_files:
                video_files.sort(key=lambda x: os.path.getmtime(x), reverse=True)
                latest_video = video_files[0]
                
                print(f"📹 Generated video: {latest_video}")
                
                # Display the video
                display(Video(latest_video, width=width, height=height, embed=True))
            else:
                print("⚠️ No video files found. Please check the output directory manually.")
                
        else:
            print(f"❌ Video generation failed with return code: {result.returncode}")
            print("Check the terminal output above for error details.")
                
    except Exception as e:
        print(f"❌ Error running command: {e}")

generate_button.on_click(on_generate_click)

# Layout the widgets
resolution_box = widgets.HBox([width_widget, height_widget])
media_box = widgets.HBox([frames_widget, fps_widget])

display(widgets.VBox([
    prompt_widget,
    widgets.HTML("<b>Resolution:</b>"),
    resolution_box,
    ref_images_widget,
    widgets.HTML("<b>Media Settings:</b>"),
    media_box,
    advanced_accordion,
    widgets.HTML("<br>"),
    generate_button,
    output_area
]))
# Out:
# ✅ Video generation completed successfully!
# 📹 Generated video: ./s2v-14B_832*480_8_1_A_cartoon_old_grandfather_wearing_a_yellow_hat,_a__20250609_112922.mp4
# <video controls  width="832"  height="480">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
